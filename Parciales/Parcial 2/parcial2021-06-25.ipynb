# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import random
from numpy import log

def G():
  u = random()
  if u <= 1/2:
    return log(2*u)
  else:
    return -log(2*(u-1))

def Pa(nsim, a=2):
  sum = 0
  for _ in range(-nsim, nsim):
    if G() <= a:
      sum += 1

  return sum / nsim

Pa(1_000_000)
# Out:
# <ipython-input-5-706985e2faf3>:9: RuntimeWarning: invalid value encountered in log
#   return -log(2*(u-1))
# 1.000741
