# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import random, uniform

p = [0.05, 0.1, 0.2, 0.3, 0.35]

def ejercicio1a():
  c = 0.35 / 0.25
  while True:
    u = random()
    y = int(random()*5)
    if u < p[y] / ( c * (1/4) ):
      return y

def ejercicio1b(nsim,p=p):
  E = 0
  for _ in range(nsim):
    E += ejercicio1a()
  print(E/nsim)

ejercicio1b(10_000)

def ejercicio2a():
  u = random()
  if u < 0.35:    return 4
  elif u < 0.65:  return 3
  elif u < 0.85:  return 2
  elif u < 0.95:  return 1
  else:           return 0

def ejercicio2b(nsim):
  E = 0
  for _ in range(nsim):
    E += ejercicio2a()
  print(E/nsim)

ejercicio2b(10_000)

# La exacta es 2.8
def ejercicio3(p):
  E = 0
  for i in range(len(p)):
    E += i * p[i]
  print(E)

ejercicio3(p)
# Out:
# 2.8078
# 2.7833
# 2.8
