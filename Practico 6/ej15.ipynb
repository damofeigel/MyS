# %%
from random import random
from scipy.stats import chi2, expon
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
datos = [1.6, 10.3, 3.5, 13.5, 18.4, 7.7, 24.3,
         10.7, 8.4, 4.9, 7.9, 12, 16.2, 6.8, 14.7]

def F(x, _lambda):
  return 1 - np.exp(-x*_lambda)
# Calculamos el estimador de maxima verosimilitud
_lambda = 1 / np.mean(datos)
# 0.09322560596643878

def KS(datos):
  datos.sort()
  n = len(datos)
  d = 0
  for j in range(n):
    x = datos[j]
    d = max(d, (j+1)/n - x, x - j/n)
  return d
# Out:
# 23.366666666666667
